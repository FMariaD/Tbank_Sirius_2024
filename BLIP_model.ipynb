# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
import os
import torch
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# ! possibly change dir_path

BATCH_SIZE = 30
DIR_PATH = r"C:\Users\FMari\Sirius2024\images_final"

# %%
class IC_model():
    """
    Класс, который принимает на вход изображения
    и выдает описания к ним
    """
    def __init__(self):
        self.processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
        self.model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large", 
                                                                  torch_dtype=torch.float16)
        
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)
        self.model.eval()
        

    def predict(self, img_paths, conditional=False, texts=None) -> str:
        """
        :img_paths: list(str) - путь, где лежит картинка
        :conditional: bool, optional - с условием или без
        :texts: list(str), optional - текст, на который должен быть ориентирован ответ
        """   
        
        images = [Image.open(path).convert(mode="RGB") for path in img_paths]
        if conditional:
            inputs = self.processor(images, 
                                    text=texts, 
                                    return_tensors="pt").to(self.device, torch.float16)
        else:
            inputs = self.processor(images, 
                                    return_tensors="pt").to(self.device, torch.float16)

        outs = self.model.generate(**inputs)
        answers = self.processor.batch_decode(outs, skip_special_tokens=True)
        
        return answers

# %%
model = IC_model()
# Out:
# C:\Users\FMari\miniconda3\envs\cuda\lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
img_paths = [os.path.join(DIR_PATH, p) for p in os.listdir(DIR_PATH)]

# %%
captions = np.empty(len(img_paths), dtype="<U100")

# %%
for idx in range(0, len(img_paths), BATCH_SIZE):
    stop = min(len(img_paths), idx + BATCH_SIZE)
    
    preds = np.array(model.predict(img_paths[idx:stop]))
    captions[idx:stop] = preds
    
    if idx % 100 == 0:
        print(idx)
# Out:
# 0
# 300

# %%
captions
# Out:
# array(['a close up of a small backpack with a zipper on the front',
#        'arafed woman in black and white striped shirt and black pants',
#        'araffe woman in red pajamas posing for a picture',
#        'woman in black coat standing in front of a window looking out',
#        'a close up of a glass bowl on a table',
#        'arafed image of a little girl in a black onesuit',
#        'there is a small christmas tree on a table with a red pot',
#        'a close up of a pair of shorts with a white trim',
#        'a woman in a pink coat and jeans standing in front of a brick wall',
#        'arafed bed with a plaid comforter and pillows on a wooden floor',
#        'someone is putting on a pair of brown shoes with holes',
#        'a close up of a black box with a green eye shadow',
#        'there is a red heart shaped object hanging from a string',
#        'pair of pink gloves with rose embroidered on the wrist',
#        'a close up of a mannequin torso with a white shirt',
#        'purple thermos are sitting on a table outside on a sunny day',
#        'a woman in a white shirt and grey pants standing next to a wall',
#        'there are two red apples hanging on a window with a green leaf',
#        'araffe woman in red shirt and black pants posing for a picture',
#        'a close up of a black sock with a diamond decoration on it',
#        'a close up of a person wearing a blue shirt and shorts',
#        'a close up of a woman in a dress posing for a picture',
#        'arafed woman in a black coat and white shirt standing in front of a brick wall',
#        'a close up of a purse on a sidewalk near a brick wall',
#        'there are a lot of small dolls that are on a table',
#        'there is a red tube with a hole in it in a room',
#        'a close up of a keychain with a cartoon character on it',
#        'arafed man in black jacket standing in front of a white wall',
#        'a black pants with a buttoned closure and a belt',
#        'there is a white toilet with a plastic seat and a white wall',
#        'there is a trash can with a bunch of toys on the floor',
#        'araffes in the fog on a foggy day with a kite flying overhead',
#        'there is a picture of a jacket hanging on a brick wall',
#        'a close up of a pair of shoes with a white background',
#        'a close up of a pair of pants with flowers on them',
#        'a close up of a pair of black shoes on a white surface',
#        'a close up of a dog bed with a flower pattern',
#        "arafed view of a person's foot in a black leather shoe",
#        'there is a black book sitting on a table with a white wall behind it',
#        'araffe woman with long hair wearing a hat and a flower in her hair',
#        'orange shirt with a vw bus and surfboards on it',
#        'a close up of a woman wearing a purple shirt and a pair of earrings',
#        'a pair of nude colored sandals with a block heel and a strap',
#        'arafed man in red shirt and plaid pants standing in front of a wall',
#        'arafed woman in blue shirt and red gloves standing in front of mirror',
#        'there is a black shoe that is on a stand on a table',
#        'a close up of a woman in a black skirt and tight pants',
#        'a close up of a person with a finger on a poster',
#        'arafed woman in a skirt and top standing in a room',
#        'a close up of a woman wearing a flower crown with a necklace',
#        'there is a red bottle and a red cup on the sidewalk',
#        'there is a small refrigerator with a shelf on the door',
#        'arafed woman in a blue coat and jeans standing in a room',
#        'a close up of a soccer ball on a brick wall',
#        'six red and white glass containers with lids on a gray surface',
#        'there is a man pulling a boat on a rope',
#        'arafed woman wearing a pink scarf and a pink hat',
#        'arafed woman wearing a pink scarf and a pink hat',
#        'a close up of a black and white shirt hanging on a wall',
#        'a woman standing in a white room with a black top and white boots',
#        'arafed woman wearing a burgundy scarf and white shirt',
#        'packaging of a cell phone in a box with a cable',
#        'a close up of a pair of white shoes with black stripes',
#        'there is a man standing in front of a projection screen',
#        'arafed girl with blue hair standing in front of a door',
#        'arafed woman in a skirt and a top standing in a room',
#        'arafed woman standing in front of a white wall wearing a black and white top',
#        'two coffee mugs with a picture of a mouse and a cat',
#        'a close up of a black and white photo of a bikini and panties',
#        'a close up of a pair of shorts with holes on them',
#        'arafed picture of a woman in tights and socks on a wall',
#        'a close up of a white shirt on a table with a tag',
#        'a close up of a pair of shoes with a shoelacee on them',
#        'arafed sock with a blue and white argyle pattern on it',
#        'a white dress with black and white cats on it',
#        'a close up of a pair of jeans with hearts on them',
#        'arafed image of a pair of shoes on a gray surface',
#        'a black and white photo of a window with a drawing of a bird',
#        'a close up of a blue tie hanging on a wall',
#        "a close up of a baby's pink snowsuit with a hood",
#        'beige slippers with holes on the back of them sitting on a tiled floor',
#        'there is a red and white picture of a bench and a red wall',
#        'there is a black briefcase sitting on the wall by the wall',
#        'woman in white shirt and black and white pants standing in front of a mirror',
#        'a close up of a pair of shoes on a white surface',
#        'there are two dogs and a cat playing in the snow',
#        'there is a shoe that is sitting on a fire hydrant',
#        'gold tone flower brooch with clear stones on a gray background',
#        'a woman standing in front of a picture of a woman in a dress',
#        'a close up of a pair of pants with a logo on the side',
#        'arafed woman in pink sweater and blue pants standing against a white brick wall',
#        'there is a white hello kitty hat with a pink bow on it',
#        'arafed woman in blue shirt and black pants standing against a wall',
#        'arafed man holding a sign with a picture of a man holding a sign',
#        'a close up of a pair of shoes with a bow on the heel',
#        'a woman in black leggings and white sneakers leaning against a wall',
#        'a woman in black leggings and white sneakers leaning against a wall',
#        'arafed woman in a beige coat and white pants standing in a room',
#        'a close up of a baby stroller in a room with a wall',
#        'a close up of a black shirt with a black design on it',
#        'a close up of a bag of legos on a table',
#        'there is a plant in a pot on a window sill',
#        'arafed woman in a red dress standing against a wall',
#        'there is a bed with a brown blanket on it in a room',
#        'a close up of a black shoe on a white brick wall',
#        'a woman in a black dress and white boots standing in a room',
#        'there are two boxes sitting on a table with a glass',
#        'arafed image of a little girl standing on a skateboard',
#        'a woman standing in front of a white wall wearing a blue top',
#        'a woman in a black top and blue jeans standing in front of a gray background',
#        'a close up of a person holding a surfboard on a brick wall',
#        'a woman in a green coat standing in a room',
#        'there is a silver shoe on a stand against a brick wall',
#        'arafed woman standing in front of a door wearing a black top and pants',
#        'a woman in a purple tank top and black leggings posing',
#        'cartoon pillow with a woman sitting on a cloud with a bird',
#        'arafed woman in a black coat standing in front of a white wall',
#        'pink shirt hanging on a white door with a brick wall',
#        'a close up of a shirt with a red and white stripe',
#        'arafed woman in a red coat standing in a doorway',
#        'there is a black shoe with a bow on the top of it',
#        'woman in a maroon suit standing in front of a brick wall',
#        'arafed image of a woman in a short dress leaning against a wall',
#        'there is a flower that is on a stem with leaves',
#        'a close up of a bottle and a cup on a table',
#        'a close up of a purple shirt with a pink collar',
#        'a close up of a pair of brown boots on a ledge',
#        'arafed view of a bed with a blanket and pillows in a bedroom',
#        'arafed image of a woman standing in front of a door',
#        'a close up of a pink shirt with a white logo on it',
#        'arafed t - shirt with a woman in a nun nun on it',
#        'there is a fire hydrant that is broken and sitting in the middle of a street',
#        'a close up of a toy truck with a box on the back',
#        'a close up of a window with a white curtain and a white wall',
#        'a close up of a pair of shoes on a black platform',
#        'arafed sign on a brick wall with a white background',
#        'a close up of a pair of black shoes on a ledge',
#        'a close up of a pair of sunglasses on a wall',
#        'a close up of a toy helicopter with a crane attached to it',
#        'purple and white tie with a pink flower pattern on it',
#        'arafed man in black hoodie and green shorts standing in a room',
#        'there is a white shoe with a flower on the side',
#        'there is a window with a pink light on it and a pink wall',
#        'arafed woman in white shirt and gray gloves posing for a picture',
#        'arafed red baby suit with a zipper on the chest',
#        'there is a room with a window, a plant, and a chair',
#        'a close up of a belt with a metal buckle on a table',
#        'yellow pants and a gray shirt are on a hanger',
#        'arafed woman in a white shirt and black pants posing for a picture',
#        'there is a small box with a blue towel in it',
#        'arafed man in a blue sweater and black pants standing in front of a brick wall',
#        'there is a small toy dog that is sitting on the floor',
#        'there is a white wall with a metal shelf on it',
#        'a close up of a pair of pants with a red belt',
#        'there is a toy truck with a money bill coming out of it',
#        'there is a woman in a black pantyhost and black stockings',
#        'purple high heeled sandals with a flower decoration on the heel',
#        'a close up of a coffee cup with a sunflower on it',
#        'a close up of a pair of shoes on a shelf',
#        'bow tie with a light blue color on a white background',
#        'there is a pillow that is sitting on a table',
#        'arafed woman in white sweater and white pants standing in front of a mirror',
#        'a close up of a pair of black shoes with black socks',
#        'arafed image of a black and white photo of a map',
#        'woman in a gray dress standing in front of a white door',
#        'there is a shell with a fish inside of it on the seat of a car',
#        'arafed man standing in front of a brick wall wearing a white t - shirt',
#        'araffes in a black and green mesh bodysuit',
#        'a close up of a pair of sandals on a shelf',
#        'there is a silver ring with a picture of a man on it',
#        'a close up of a knitted hat on a mannequin head',
#        'there is a cat that is standing on a corner of a room',
#        'purple and white drawing of a laptop and a cell phone',
#        'a woman in a black and white polka dot dress',
#        'a close up of a shirt with a cartoon character on it',
#        'a close up of a watch on a brick wall with a brick wall in the background',
#        'there is a green and white toothbrush on a stand against a brick wall',
#        'arafed woman in a gray tank top and blue leggings',
#        'a woman in a black leather jacket standing in front of a white backdrop',
#        'a close up of a man in a white shirt and black pants',
#        'a close up of a lipstick on a table near a brick wall',
#        'a pair of purple paper on a white brick wall',
#        'pair of green jade earrings on a branch in a room',
#        'a close up of a bag of plastic building blocks on a table',
#        'a woman in a tan coat and blue jeans posing for a picture',
#        'arafed girl in a blue shirt with a sequined love sign',
#        'a close up of a mannequin head wearing a blue hat',
#        'a close up of a white wall with a gray paint',
#        'a picture of a black jacket with a red and white logo on it',
#        'arafed woman in a green jacket and black skirt standing in a room',
#        'a close up of a red and white door with a red stripe',
#        'a black t - shirt with a white logo on the chest',
#        'arafed window with blinds in a room with a couch',
#        'there is a blue umbrella that is hanging on a wall',
#        'arafed image of a man standing in front of a door',
#        'there is a backpack hanging on a wall with a white wall behind it',
#        'a yellow t - shirt with a car and a number one on it',
#        'boy in a blue shirt and black pants standing with his hands in his pockets',
#        'a close up of a woman wearing a pink dress and a necklace',
#        'there is a bed with a floral comforter on it in a room',
#        'arafed boy in white shirt and black pants standing with his hands on his hips',
#        'there is a man that is skateboarding on a ramp in a room',
#        'there is a shoe hanging on a wall with a tile background',
#        'a woman in white pants and a white sweater stands against a white brick wall',
#        "a close up of a baby's pants hanging on a brick wall",
#        'arafed woman in a pink hoodie standing in front of a white wall',
#        'woman wearing a gray hat and scarf standing in front of a mirror',
#        'a close up of a black leggings on a white brick wall',
#        'a close up of a tie on a shelf with a wall in the background',
#        "a close up of a pair of men's underwear with a red waistband",
#        'there is a picture of a shirt on a table with a knife',
#        'a woman standing in front of a white wall wearing a zebra print shirt',
#        'woman wearing black gloves and a white shirt posing for a picture',
#        'woman in white shirt dress with brown belt posing against brick wall',
#        'a close up of a red pocket square with a white border',
#        'arafed man in black tank top standing in a room',
#        'a close up of a pair of black boots on a white surface',
#        'arafed picture of a woman walking down a street past a store',
#        'arafed woman in black top and leggings posing for a picture',
#        'there are three pieces of paper hanging from the ceiling of a room',
#        'there is a vase with flowers on a table in front of a brick wall',
#        'woman in a green coat and black pants standing on a white floor',
#        'there is a white staircase leading to a white wall',
#        'a close up of a pair of shoes with a white background',
#        'woman leaning against a wall with her hands on her hips',
#        'a close up of a bed with a pink comforter and a white nightstand',
#        'a woman in a blue dress standing in front of a brick wall',
#        'there is a pair of glasses sitting on a window sill',
#        'blond woman with a black dress and a black belt',
#        'there is a book with a picture of a man sitting on a bench',
#        'a woman in a short dress poses for a picture',
#        'laccoste white sneakers with red logo on the sole',
#        'a close up of a plate with a gold rim on a gray surface',
#        'a close up of a woman wearing a pair of earrings',
#        'arafed image of a girl in a blue and white jacket and pants',
#        "a woman's bra top sitting on top of a bed",
#        'a close up of a glove on a mannequin base',
#        'arafed woman in a blue dress standing against a wall',
#        'arafed woman in a pink dress posing for a picture',
#        'a woman in a red shirt and grey pants standing',
#        'a woman in a brown and yellow shirt and maroon pants',
#        'a person standing in front of a projection screen with a white shirt on',
#        'a close up of a camouflage neck gaiter on a table',
#        'arafed man in a white sweater and brown pants standing in front of a window',
#        'there are four different pictures of a man brushing his teeth',
#        'araffe woman in black and white plaid pants leaning against a wall',
#        'someone is holding a pair of socks with a star on them',
#        'arafed woman in black dress and white boots standing in front of a window',
#        'a woman in a green coat standing in front of a brick wall',
#        'someone is standing on a brick wall wearing red shoes',
#        'a close up of a purse with a zipper on the inside',
#        'there is a pink backpack sitting on the floor in a room',
#        'there is a black and white photo of a man standing in the water',
#        'there is a table and chairs in a room with a window',
#        'a black backpack sitting on top of a skateboard on a skateboard',
#        'arafed woman in a green jacket and a white scarf',
#        'a bag of green tea on a brick wall',
#        'a woman in a blue shirt and jeans posing for a picture',
#        'a close up of a box with a bunch of different colored stones',
#        'a man in a black shirt and pants standing in front of a brick wall',
#        'a close up of a panda bear with a butterfly on its nose',
#        'a close up of a person wearing a purple jacket and a black hat',
#        'a white shirt with black dots on it sitting on a wall',
#        'there is a black toilet in a bathroom with a window',
#        'a close up of a white shorts with a black logo on it',
#        'a close up of a bottle of syrup next to a box',
#        'a close up of a pair of rain boots with snakes on them',
#        'arafed woman in a pink sweater and jeans standing in front of a white closet',
#        'a close up of a toilet paper roll on a wall',
#        'a white sneaker with black soles on a shelf',
#        'arafed woman in a skirt and shirt standing in front of a brick wall',
#        'arafed man in green trunks with no shirt and no shirt',
#        'there is a picture of a white wall with a bunch of different things on it',
#        'a woman in a coat and a backpack standing in front of a wall',
#        'there is a black shoe with a lace on it on a white surface',
#        'a woman in a white sweater and jeans posing for a picture',
#        'a close up of a bottle of formula ampoule with a box',
#        'arafed man in a white hoodie and jeans standing against a wall',
#        'there is a bouquet of flowers that is on a table',
#        'there is a toy bus that is sitting on the ground',
#        'there are two blue vases with flowers in them on a table',
#        'arafed woman in a silver coat standing in a room',
#        'yellow baby romper with white collar and buttons on the front',
#        'a close up of a swimsuit with a clock on it',
#        'a woman in a white top and black pants standing in front of a wall',
#        "a close up of a woman's panties with polka dots",
#        'there is a black and white toilet brush holder in a white room',
#        'there is a box with a toy truck inside of it',
#        'there are two cups and saucers on a plate on a table',
#        'a picture of a picture of a picture of a picture of a picture of a picture of a',
#        'a close up of a white pitcher on a shelf on a wall',
#        'a close up of a woman in a green panties and panties',
#        'a close up of a pair of shoes with a mouse on them',
#        'two black boxes with a white logo on them sitting on a table',
#        'arafed woman in black shirt and jeans standing in a room',
#        'a close up of a white flower on a wall near a bed',
#        'a close up of a baby sleeping bag on a white surface',
#        'araffe bed with a white cover and a white pillow',
#        "there is a woman's hat that is on a mannequin head",
#        'there is a laptop on a black table with a bag of plastic',
#        'a woman in a brown and yellow shirt and maroon pants',
#        'yellow umbrellas are sitting on the ground next to a window',
#        'there is a box with a floral design on it',
#        'there is a picture of a little girl looking out a window',
#        'a woman standing in a room with a wall painted in a pattern',
#        'there are two pictures of a toy truck with a rocket on top',
#        "a close up of a person's underwear with a white background",
#        'arafed orange slice on a white brick wall with a white brick wall',
#        'a woman standing in front of a brick wall wearing a maroon sweater and black pants',
#        'a close up of a pair of black shoes hanging on a wall',
#        'a close up of two cell phones with a person pointing at them',
#        'a close up of a picture of a cat on a table',
#        'there is a water bottle with a straw inside of it',
#        'arafed woman wearing a pink hat and a pink coat',
#        'there is a white refrigerator with a white door and a white handle',
#        'a close up of a purse hanging on a wall near a brick wall',
#        'a bottle of detere with lemon and mint leaves on it',
#        'a close up of a bottle and a cup on a table',
#        'a woman in a red shirt and black pants standing in front of a brick wall',
#        'arafed man in a purple shirt and blue pants standing',
#        'arafed shirt hanging on a wall in a room',
#        'there is a glass of orange juice with a slice of orange',
#        'a close up of a wall with a painting of a heart and the word love',
#        'a pair of black shoes with a silver heel',
#        'a woman in a black bodysuit standing on a white surface',
#        'woman wearing a gray hat and scarf with a white shirt',
#        'sunglasses hanging on a wall with a shadow of a person',
#        'there is a small white refrigerator with a black door',
#        'a close up of a purse hanging on a chain',
#        'a close up of a pot of milk on a counter',
#        'a close up of a wallet on a white surface with a black background',
#        'arafed man standing in front of a brick wall wearing jeans',
#        'a close up of a belt on a shelf with a white background',
#        'arafed image of a girl in a gray and white suit',
#        'araffe woman in red lingersuit showing off her underwear',
#        'woman wearing a jacket and black pants standing in front of a white wall',
#        'someone is making a sand sculpture on the beach with a sand clock',
#        'woman standing on a scale in front of a door with a pink and purple pattern',
#        'arafed woman in a blue and white sweater and blue leggings',
#        'a close up of a white shirt on a brick wall',
#        'arafed woman in a sweater and skirt holding a plant',
#        'a black sweatshirt hanging on a wall with a white wall',
#        'a close up of a pair of shoes on a white surface',
#        'arafed woman in a pink tank top and denim shorts standing in front of a door',
#        'there are two cats sitting on a table with a hot dog',
#        'a close up of a small backpack with a zipper on the front',
#        'there is a black and white photo of a pair of shoes',
#        'a woman in a green hoodie and jeans standing against a wall',
#        'a woman in a black dress with a leopard belt',
#        'a close up of a cell phone with a white background',
#        'arafed image of a woman in a red dress and heels',
#        'there is a tag with a hair comb on it hanging on a wall',
#        'a close up of a picture of a bird made of dots',
#        'a close up of a tie on a white surface',
#        'a close up of a black sandal with a strap on the side',
#        'there is a baby sitting in a glass case with a cow on it',
#        'arafed man standing in front of a white door with his hands on his hips',
#        'a close up of a metal door with a red handle',
#        'a woman wearing a denim jacket and a scarf',
#        'a close up of a poster on a wall with a picture of a bunch of oranges',
#        'arafed man standing in a doorway with his hands in his pockets',
#        'there are two red earrings hanging from a window sill',
#        'wallet with two compartments on top of a table next to a window',
#        'a woman in a white coat standing in front of a brick wall',
#        'there is a picture of a glove, glove and glove on a wall',
#        'hp 22 ink cartridges for hp printers',
#        'cartoon of a man in a suit and tie standing next to a sign',
#        'arafed man in a black shirt and brown pants standing in front of a wall',
#        'there are two glasses on a shelf in a room',
#        'a close up of a box of a product on a table',
#        'there is a pair of pink rain boots hanging on a wall',
#        'arafed woman with a pink hat and a red dress',
#        'a close up of a bottle of liquid on a table',
#        'a close up of a pair of shoes on a gray surface',
#        "a close up of a person's hand wearing a black glove",
#        'packaging of a blue and white toy with a red and white object',
#        'a close up of a red and black object on a table',
#        'there is a pair of shoes on the wall next to a toilet',
#        'arafed girl with long black hair smiling and holding a plate of food',
#        'there is a black and white photo of a purse and a book',
#        'purple stars and stars case for iphone 5',
#        'a close up of a tie hanging on a door with a white background',
#        'a close up of a can of food on a table',
#        'a close up of a white envelope with a label on it',
#        'a close up of a gold statue of a bird with wings spread',
#        'arafed view of a pair of shoes on a tiled floor',
#        'a close up of a microwave oven on a white wall',
#        'a close up of a pair of pants on a stand',
#        'a white curtain hanging from a window in a room',
#        'a close up of a mirror with a makeup case on it',
#        'arafed woman in a white coat and black boots standing in a studio',
#        'pair of earrings with orange stones and diamonds on a gray background',
#        'a close up of a woman in a purple dress standing in front of a brick wall',
#        'adidas hooded sweatshirt with hoodie and hoodie',
#        'a white shirt with a ruffled neckline on a gray surface',
#        'a woman in a hat and dress standing in front of a wall',
#        'a close up of a black plastic chair on a gray floor',
#        'a close up of a pink clogger with a cartoon character on it',
#        'a close up of a pair of sandals with a red and blue strap',
#        'arafed doll wearing a knitted hat and sweater',
#        'a close up of a pair of sunglasses with a white background',
#        'a close up of a piece of paper with a tie on it',
#        'a close up of a pair of blue shoes with a white sole',
#        'a woman in a blue dress standing against a wall',
#        'there is a metal book holder with a flower design on it',
#        'there is a small white box with a window on it',
#        'there is a close up of a pair of shoes with a shoelace',
#        'a close up of a bracelet with green stones on it',
#        'a close up of a pair of sandals with a flower on the heel',
#        'arafed image of a little girl in a yellow jacket and jeans',
#        'a close up of a pair of socks hanging on a wall',
#        'a close up of a coffee pot and a cup on a table',
#        'araffes in a blue top and pink shorts standing in front of a brick wall',
#        'a close up of a roller shade with a blue and purple design',
#        'there is a picture of a suit and tie on a door',
#        'a woman in a white shirt and black pants posing for a picture',
#        'a woman in a floral one piece swimsuit posing for a picture',
#        'arafed photograph of a man in a space suit with a baseball bat',
#        'arafed woman in a blue shirt and grey pants standing',
#        'a close up of a woman in a white shirt and purple pants',
#        'a close up of a woman in a white shirt and purple pants',
#        'there is a young girl standing on a step in front of a picture',
#        'a close up of a pair of sandals on a shelf',
#        'someone is brushing their teeth in a messy room with a chair',
#        'arafed woman in a pink coat and blue jeans standing in front of a white wall',
#        'there is a black and white photo of a skateboarder doing a trick',
#        'a close up of a group of underwear on a gray surface',
#        'arafed woman in a gray dress walking on a wooden floor',
#        'araffed woman in black bra top and panties taking selfie',
#        'yellow phone holder with a yellow cord attached to it',
#        'there is a red suitcase with a handle and a handle',
#        'a close up of a pair of shoes on a shelf',
#        'there is a white sink with a metal drain in it',
#        'yellow t - shirt with green trim on a gray background',
#        'there is a poster on the wall of a building advertising a movie',
#        'someone is holding a bag with a pattern of birds on it',
#        'arafed woman in a blue dress standing in front of a brick wall',
#        'a close up of a mannequin head with a necklace on it',
#        'a close up of a pair of black shoes on a white surface',
#        'a woman standing in a room with a white wall and a white floor',
#        'araff hat with a black fur ball on a wall',
#        'araffe woman in a red dress standing on a staircase',
#        'a close up of a diamond ring with a diamond on top',
#        'there is a small gray tray sitting on a table',
#        'arafed woman wearing a red scarf and black pants',
#        'a close up of a purse with a tag on it',
#        'a close up of a hat with a star pattern on it',
#        'arafed woman in a purple robe talking on a cell phone',
#        'there is a toy dog that is in a box with a hand',
#        'arafed image of a pair of shoes with a flower on the heel',
#        'three brown vases sitting on a shelf with apples and apples',
#        'there is a red wire that is connected to a white wall',
#        'there is a yellow plate with a yellow cookie on it',
#        'there is a picture of a picture of a kitchen with a stove and a microwave',
#        'there is a picture of a picture of a kitchen with a stove and a microwave',
#        'woman in black lingerie posing in front of mirror in room',
#        'arafed woman in white shirt and pants standing in front of a white wall',
#        'woman in white shirt and black pants standing in front of a white board',
#        'arafed man in a blue suit standing in a room',
#        'a close up of a sign with a hand pointing at it',
#        'a close up of a pair of shoes on a shelf',
#        'a close up of a pair of shoes on a shelf',
#        'a close up of a person wearing a red bracelet and a white shirt',
#        'a man in a black jacket and red shirt walking',
#        'a close up of a bed in a room with a brick wall',
#        'a close up of a pair of earrings with a diamond on them',
#        'yellow plastic cups with white lids are stacked on a shelf',
#        'a close up of a bench on a white surface with a shadow',
#        'a close up of a young boy in a pink shirt and black pants',
#        'a close up of a small backpack with a zipper on the front'],
#       dtype='<U100')

# %%
DIR2SAVE = r"C:\Users\FMari\Sirius2024\short_captions"

# %%
filenames = os.listdir(DIR_PATH)

for idx in range(len(img_paths)):
    caption = captions[idx]
    name = filenames[idx].split('.')[0]
    with open(os.path.join(DIR2SAVE, name+".txt"), "w") as f:
        f.write(caption)
